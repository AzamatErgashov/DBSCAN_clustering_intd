# %%
from IPython.display import Image

# %% [markdown]
# # klasterlash
#
# - DBSCAN zichlik asosida klasterlash

# %%
Image('dbscan.jpg',width=700)

# %% [markdown]
# ## mana korib turibsiz chapdagi oddiy k-means algoritimida klasterlash
# # ongdagi zichlik asosida klasterlash dbscan orqali klasterlash dbscan orqali biz bir klaster ichidagi boshqa bir klasni ham topa olamiz dbscan algoritimi sal murakkab tuzilgan
# ## dbscan shakil turli hildagi bolgan klasterlarni ham aniqlay oladi

# %%
Image('dbscan_k-means.jpg', width=700)

# %% [markdown]
# # k-means noodatiy qiymatlarni ham klasterga tiqib yuboradi bu bizga model aniqligini kamayishida va misol uchun firibgarlarni aniqlashda tosqinlik qilishi mumkin

# %% [markdown]
# # zichlik asosidagi algoritimlar esa joylashgan hududni birlashtirib noodatiy qiymatlarni ajratib beradi

# %% [markdown]
# # zichlik algoritimlaridan biri bu dbscan toliq nomi density-based spatial clustering of application with noise
# - eng kop qollaniladigan algoritim
# - asosiy goya biror nuqta klasterga tegishli bolsa boshqa koplab nuqtalar bolishi kerak
# # asosiy parametr
# - R(qoshni nuqtalar radiuse) - berilgan radiusdagi qushnilar soni
# - M - minumum qoshnilar soni nuqtalar oraligini belgilaymiz masalan 5 osha 5 oraligidagilarni(qoshnilarni) bitta klasterga yigadi

# %%
Image('dbscanqandayishlaydi?.jpg',width=700)

# %% [markdown]
# # R radius M qoshnilar soni nuqtalarni 3 turga boladi rasmda bor

# %%
Image('dbscan2.jpg', width=700)

# %% [markdown]
# # core yani markaz bolishi uchun kamida rasius bl m nuqta tushishi kerak hozir tushmoqda bizda qizil nuqta markaz

# %%
Image('dbscan3.jpg', width=700)

# %% [markdown]
# # endi m nuqtalar soni kam shu uchun markaz nuqta emas chegaraviy(border) nuqta deyiladi

# %% [markdown]
# # border point bolishi uchun M nuqtalar berilganidan kam yoki core(markaz) point bilan qoshini bolishi kerak

# %%
Image('outlider.jpg', width=600)

# %% [markdown]
# # 3-kategoriya hech bir qoshinisi bolmasa outlider bolib qoladi

# %%
Image('theend.jpg', width=500)
